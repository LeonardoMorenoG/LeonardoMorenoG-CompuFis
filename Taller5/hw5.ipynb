# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import numpy as np
import sys 
import pylab
import scipy

data = np.loadtxt("monthrg.dat")
manchas = []
anios = []
promedios=[]
for item in data:
   if( item[0] >= 1800):
        
           manchas.append(item[3])
	   anios.append(item[0] + item[1]/12.0)


plt.plot(anios,manchas)

# %%
from scipy.fftpack import fft, fftfreq
n = len(anios) # number of point in the whole interval
f = 200.0 #  frequency in Hz
dt = 1.0 / (12.0) #32 samples per frequency
fft_x = fft(manchas) / n # FFT Normalized
freq = fftfreq(len(anios), dt) # Recuperamos las frecuencias
plt.plot(freq,np.abs(fft_x))
print freq
# Out:
# [ 0.          0.00510204  0.01020408 ..., -0.01530612 -0.01020408
#  -0.00510204]

# %%
potencias = []
for item in fft_x:
    potencias.append(np.abs(item)**2)
plt.plot(freq,potencias)

# %%
frecuenciasAnios=[]
for item in freq:
    frecuenciasAnios.append(item)
for item in frecuenciasAnios:
    indice = frecuenciasAnios.index(item)
    valor = 1/item
    frecuenciasAnios[indice]=valor
frecuenciasAnios[0]=0
periodo = []
potencias2 = []
for item in frecuenciasAnios:
    if 1<=item and item<=20:
        indice = frecuenciasAnios.index(item)
        periodo.append(item)
        potencia = potencias[indice]
        potencias2.append(potencia)
print len(frecuenciasAnios)
print len(potencias)
print periodo
print len(potencias2)
plt.plot(periodo,potencias2)
# Out:
# 2352
# 2352
# [19.600000000000001, 17.81818181818182, 16.333333333333332, 15.076923076923078, 14.0, 13.066666666666668, 12.250000000000002, 11.529411764705882, 10.888888888888889, 10.315789473684211, 9.8000000000000007, 9.3333333333333339, 8.9090909090909101, 8.5217391304347831, 8.1666666666666661, 7.8399999999999999, 7.5384615384615392, 7.2592592592592604, 7.0, 6.7586206896551726, 6.5333333333333341, 6.3225806451612909, 6.1250000000000009, 5.9393939393939394, 5.7647058823529411, 5.6000000000000005, 5.4444444444444446, 5.2972972972972974, 5.1578947368421053, 5.0256410256410264, 4.9000000000000004, 4.7804878048780495, 4.666666666666667, 4.558139534883721, 4.454545454545455, 4.3555555555555561, 4.2608695652173916, 4.1702127659574471, 4.083333333333333, 4.0000000000000009, 3.9199999999999999, 3.8431372549019613, 3.7692307692307696, 3.6981132075471703, 3.6296296296296302, 3.5636363636363639, 3.5, 3.4385964912280702, 3.3793103448275863, 3.3220338983050848, 3.2666666666666671, 3.2131147540983611, 3.1612903225806455, 3.1111111111111116, 3.0625000000000004, 3.0153846153846158, 2.9696969696969697, 2.9253731343283582, 2.8823529411764706, 2.8405797101449282, 2.8000000000000003, 2.7605